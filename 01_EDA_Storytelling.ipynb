# %%
# 1. Cấu hình tự động reload code (Chạy cell này đầu tiên)
# %load_ext autoreload
# %autoreload 2

# %%
# 2. Import class vừa viết từ thư mục src
import sys
# Đảm bảo Jupyter nhìn thấy thư mục gốc của project
sys.path.append('..')

# %%
from src.data_loader import DataLoader

# %%
# 3. Khởi tạo và nạp đạn!
loader = DataLoader(raw_data_path='../data/raw')
raw_data = loader.load_all_data()
# Out:
# Đang nạp dữ liệu gốc...
# e:\DATATHON 2026\datathon-2026-round-1\notebook\..\src\data_loader.py:21: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath, parse_dates=date_cols)
# ✅ Đã nạp thành công 13 bảng dữ liệu!

# %%
# 4. Kiểm tra thử 1 bảng xem datetime đã chuẩn chưa
sales_df = raw_data['sales']
display(sales_df.head(3))
print("\nKiểu dữ liệu cột Date:", sales_df['Date'].dtype)
# Out:
#         Date     Revenue        COGS
# 0 2012-07-04  5123547.94  3982991.19
# 1 2012-07-05  2751773.45  2150580.23
# 2 2012-07-06  3054029.42  2517632.84
# Kiểu dữ liệu cột Date: datetime64[ns]
